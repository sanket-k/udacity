# %%
'''import requests
#r = requests.get('https://docs.python.org/3.json')
#r = requests.get('https://github.com/timeline.json')
r = requests.get('https://torrentz2.eu/cbc213731a7b709a80822517589bf3d12b900fdd.json')
r.json()'''
# Out:
# "import requests\n#r = requests.get('https://docs.python.org/3.json')\n#r = requests.get('https://github.com/timeline.json')\nr = requests.get('https://torrentz2.eu/cbc213731a7b709a80822517589bf3d12b900fdd.json')\nr.json()"

# %%
import csv
import pandas as pd

# %%
datafile = "745090.csv"

# %%
data = pd.read_csv(datafile,index_col=[0])
data.head()
# Out:
#                   Time (HH:MM)  ETR (W/m^2)  ETRN (W/m^2)  GHI (W/m^2)  \
# Date (MM/DD/YYYY)
# 01-01-2005               01:00            0             0            0
# 01-01-2005               02:00            0             0            0
# 01-01-2005               03:00            0             0            0
# 01-01-2005               04:00            0             0            0
# 01-01-2005               05:00            0             0            0
#
#                    GHI source  GHI uncert (%)  DNI (W/m^2)  DNI source  \
# Date (MM/DD/YYYY)
# 01-01-2005                  2               0            0           2
# 01-01-2005                  2               0            0           2
# 01-01-2005                  2               0            0           2
# 01-01-2005                  2               0            0           2
# 01-01-2005                  2               0            0           2
#
# ...

# %%
data.describe()
# Out:
#        ETR (W/m^2)  ETRN (W/m^2)  GHI (W/m^2)  GHI source  GHI uncert (%)  \
# count    98.000000     98.000000    98.000000        98.0       98.000000
# mean    177.632653    554.918367    51.897959         2.0        3.428571
# std     258.983118    678.657250    92.795473         0.0        3.979328
# min       0.000000      0.000000     0.000000         2.0        0.000000
# 25%       0.000000      0.000000     0.000000         2.0        0.000000
# 50%       0.000000      0.000000     0.000000         2.0        0.000000
# 75%     347.000000   1415.000000    79.750000         2.0        8.000000
# max     702.000000   1415.000000   376.000000         2.0        8.000000
#
#        DNI (W/m^2)  DNI source  DNI uncert (%)  DHI (W/m^2)  DHI source  \
# count    98.000000        98.0       98.000000    98.000000        98.0
# mean     32.479592         2.0        6.428571    41.244898         2.0
# std      87.991240         0.0        7.461240    68.627346         0.0
# ...

# %%
data.shape
# Out:
# (98, 67)
