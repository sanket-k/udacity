# %%
my_list = ['apple', 'banana', 'grapes', 'pear']
for c,values in enumerate(my_list,1):
    print(c,values)
# Out:
# 1 apple
# 2 banana
# 3 grapes
# 4 pear

# %%
# Your task is to read the input DATAFILE line by line, and for the first 10 lines (not including the header)
# split each line on "," and then for each line, create a dictionary
# where the key is the header title of the field, and the value is the value of that field in the row.
# The function parse_file should return a list of dictionaries,
# each data line in the file being a single list entry.
# Field names and values should not contain extra whitespace, like spaces or newline characters.
# You can use the Python string method strip() to remove the extra whitespace.
# You have to parse only the first 10 data lines in this exercise,
# so the returned list should have 10 entries!
import os

DATADIR = ""
DATAFILE = "beatles-diskography.csv"


def parse_file(datafile):
    data = []
    with open(DATAFILE, "rb") as f:
        header = f.readline().split(",")
        counter = 0
        for line in f:
            if counter == 10:
                break
            fields = line.split(",")
            entry = {}
            
            for i,value in enumerate(fields):
                entry[header[i].strip()] = value.strip()
            
            data.append(entry)
            counter +=1
    return data


def test():
    # a simple test of your implemetation
    datafile = os.path.join(DATADIR, DATAFILE)
    d = parse_file(DATAFILE)
    firstline = {'Title': 'Please Please Me', 'UK Chart Position': '1', 'Label': 'Parlophone(UK)', 'Released': '22 March 1963', 'US Chart Position': '-', 'RIAA Certification': 'Platinum', 'BPI Certification': 'Gold'}
    tenthline = {'Title': '', 'UK Chart Position': '1', 'Label': 'Parlophone(UK)', 'Released': '10 July 1964', 'US Chart Position': '-', 'RIAA Certification': '', 'BPI Certification': 'Gold'}

    assert d[0] == firstline
    assert d[9] == tenthline

    
test()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-ae44989f34e2> in <module>()
#      44
#      45
# ---> 46 test()
#
# <ipython-input-2-ae44989f34e2> in test()
#      36     # a simple test of your implemetation
#      37     datafile = os.path.join(DATADIR, DATAFILE)
# ---> 38     d = parse_file(DATAFILE)
#      39     firstline = {'Title': 'Please Please Me', 'UK Chart Position': '1', 'Label': 'Parlophone(UK)', 'Released': '22 March 1963', 'US Chart Position': '-', 'RIAA Certification': 'Platinum', 'BPI Certification': 'Gold'}
#      40     tenthline = {'Title': '', 'UK Chart Position': '1', 'Label': 'Parlophone(UK)', 'Released': '10 July 1964', 'US Chart Position': '-', 'RIAA Certification': '', 'BPI Certification': 'Gold'}
#
# <ipython-input-2-ae44989f34e2> in parse_file(datafile)
#      17     data = []
#      18     with open(DATAFILE, "rb") as f:
# ---> 19         header = f.readline().split(",")
#      20         counter = 0
#      21         for line in f:
#
# TypeError: a bytes-like object is required, not 'str'

# %%
import csv

# %%
DATADIR = ""
DATAFILE = "beatles-diskography.csv"

def parse_csv(datafile):
    data = []
    n = 0
    with open(datafile,'rb') as f:
        r = csv.DictReader(f)
        for line in r:
            data.append(line)
    return data

# %%
if __name__ == '__main__':
    datafile = os.path.join(DATADIR,DATAFILE)
    parse_csv(datafile)
    d = parse_csv(datafile)
    pprint.pprint(d)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-5-e561b7a278f0> in <module>()
#       1 if __name__ == '__main__':
#       2     datafile = os.path.join(DATADIR,DATAFILE)
# ----> 3     parse_csv(datafile)
#       4     d = parse_csv(datafile)
#       5     pprint.pprint(d)
#
# <ipython-input-4-38e19b42cc46> in parse_csv(datafile)
#       7     with open(datafile,'rb') as f:
#       8         r = csv.DictReader(f)
# ----> 9         for line in r:
#      10             data.append(line)
#      11     return data
#
# F:\anaconda3\envs\udacity\lib\csv.py in __next__(self)
#     109         if self.line_num == 0:
#     110             # Used only for its side effect.
# --> 111             self.fieldnames
#     112         row = next(self.reader)
#     113         self.line_num = self.reader.line_num
#
# F:\anaconda3\envs\udacity\lib\csv.py in fieldnames(self)
#      96         if self._fieldnames is None:
#      97             try:
# ---> 98                 self._fieldnames = next(self.reader)
#      99             except StopIteration:
#     100                 pass
#
# Error: iterator should return strings, not bytes (did you open the file in text mode?)

# %%
parse_csv(datafile)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-6-d9e4741c8246> in <module>()
# ----> 1 parse_csv(datafile)
#
# <ipython-input-4-38e19b42cc46> in parse_csv(datafile)
#       7     with open(datafile,'rb') as f:
#       8         r = csv.DictReader(f)
# ----> 9         for line in r:
#      10             data.append(line)
#      11     return data
#
# F:\anaconda3\envs\udacity\lib\csv.py in __next__(self)
#     109         if self.line_num == 0:
#     110             # Used only for its side effect.
# --> 111             self.fieldnames
#     112         row = next(self.reader)
#     113         self.line_num = self.reader.line_num
#
# F:\anaconda3\envs\udacity\lib\csv.py in fieldnames(self)
#      96         if self._fieldnames is None:
#      97             try:
# ---> 98                 self._fieldnames = next(self.reader)
#      99             except StopIteration:
#     100                 pass
#
# Error: iterator should return strings, not bytes (did you open the file in text mode?)

# %%
import pandas as pd

# %%
data = pd.read_csv('beatles-diskography.csv')
data
# Out:
#                                     Title           Released  \
# 0                        Please Please Me      22 March 1963
# 1                        With the Beatles   22 November 1963
# 2           Beatlemania! With the Beatles   25 November 1963
# 3              Introducing... The Beatles    10 January 1964
# 4                       Meet the Beatles!    20 January 1964
# 5                         Twist and Shout    3 February 1964
# 6               The Beatles' Second Album      10 April 1964
# 7            The Beatles' Long Tall Sally        11 May 1964
# 8                      A Hard Day's Night       26 June 1964
# 9                                     NaN       10 July 1964
# 10                          Something New       20 July 1964
# 11                       Beatles for Sale    4 December 1964
# 12                            Beatles '65   15 December 1964
# 13                             Beatles VI       14 June 1965
# 14                                  Help!      6 August 1965
# 15                                    NaN     13 August 1965
# 16                            Rubber Soul    3 December 1965
# 17                                    NaN    6 December 1965
# 18                    Yesterday and Today       15 June 1966
# 19                               Revolver      5 August 1966
# 20                                    NaN      8 August 1966
# 21  Sgt. Pepper's Lonely Hearts Club Band        1 June 1967
# 22                   Magical Mystery Tour   27 November 1967
# 23                            The Beatles   22 November 1968
# 24                       Yellow Submarine    13 January 1969
# 25                             Abbey Road  26 September 1969
# 26                              Let It Be         8 May 1970
#
#                            Label UK Chart Position US Chart Position  \
# 0                 Parlophone(UK)                 1                 —
# 1                 Parlophone(UK)                 1                 —
# 2                   Capitol(CAN)                 —                 —
# 3                    Vee-Jay(US)                 —                 2
# 4                    Capitol(US)                 —                 1
# 5                   Capitol(CAN)                 —                 —
# 6                    Capitol(US)                 —                 1
# 7                   Capitol(CAN)                 —                 —
# 8          United Artists(US)[C]                 —                 1
# 9                 Parlophone(UK)                 1                 —
# 10                   Capitol(US)                 —                 2
# 11                Parlophone(UK)                 1                 —
# 12                   Capitol(US)                 —                 1
# 13   Parlophone(NZ), Capitol(US)                 —                 1
# 14                Parlophone(UK)                 1                 —
# 15                Capitol(US)[C]                 —                 1
# 16                Parlophone(UK)                 1                 —
# 17                Capitol(US)[C]                 —                 1
# 18                   Capitol(US)                 —                 1
# 19                Parlophone(UK)                 1                 —
# 20                Capitol(US)[C]                 —                 1
# 21   Parlophone(UK), Capitol(US)                 1                 1
# 22   Parlophone(UK), Capitol(US)             31[D]                 1
# 23        Apple(UK), Capitol(US)                 1                 1
# 24        Apple(UK), Capitol(US)                 3                 2
# 25        Apple(UK), Capitol(US)                 1                 1
# 26  Apple(UK),United Artists(US)                 1                 1
#
#    BPI Certification RIAA Certification
# 0               Gold           Platinum
# 1           Platinum               Gold
# 2                NaN                NaN
# 3                NaN                NaN
# 4                NaN         5xPlatinum
# 5                NaN                NaN
# 6                NaN         2xPlatinum
# 7                NaN                NaN
# 8                NaN         4xPlatinum
# 9               Gold                NaN
# 10               NaN           Platinum
# 11              Gold           Platinum
# 12               NaN         3xPlatinum
# 13               NaN           Platinum
# 14          Platinum                NaN
# 15               NaN         3xPlatinum
# 16          Platinum                NaN
# 17               NaN         6xPlatinum
# 18               NaN         2xPlatinum
# 19          Platinum                NaN
# 20               NaN         5xPlatinum
# 21        3xPlatinum        11xPlatinum
# 22          Platinum         6xPlatinum
# 23          Platinum        19xPlatinum
# 24            Silver           Platinum
# 25        2xPlatinum        12xPlatinum
# 26              Gold         4xPlatinum
